# %% [markdown]
# <a href="https://colab.research.google.com/github/FrancoisHUP/TP2_INF889G/blob/main/INF889G_TP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TP2 INF 889G H24
#
# François Huppé-Marcoux
#
# Guillaume Carignan

# %% [markdown]
# ## Setup

# %%
# !pip install opencv-python

# %%
# Pull data from github
import os
import requests

data_urls = [
  'https://raw.githubusercontent.com/FrancoisHUP/TP2_INF889G/main/data/Rainier1.png',
  'https://raw.githubusercontent.com/FrancoisHUP/TP2_INF889G/main/data/Rainier2.png',
  'https://raw.githubusercontent.com/FrancoisHUP/TP2_INF889G/main/data/Rainier3.png',
  'https://raw.githubusercontent.com/FrancoisHUP/TP2_INF889G/main/data/Rainier4.png',
  'https://raw.githubusercontent.com/FrancoisHUP/TP2_INF889G/main/data/Rainier5.png',
  'https://raw.githubusercontent.com/FrancoisHUP/TP2_INF889G/main/data/Rainier6.png',
]

# create data rep
if not os.path.exists('data'):
    os.makedirs('data')

# download images
for url in data_urls:
  r = requests.get(url)
  filename = url.split('/')[-1]
  with open('data/' + filename, 'wb') as f:
      f.write(r.content)


code_urls = [
  'https://raw.githubusercontent.com/FrancoisHUP/TP2_INF889G/main/data/harris_image.py',
  'https://raw.githubusercontent.com/FrancoisHUP/TP2_INF889G/main/data/panorama_image.py',
]

# download images
for url in code_urls:
  r = requests.get(url)
  filename = url.split('/')[-1]
  with open(filename, 'wb') as f:
      f.write(r.content)

# %%
# plot image
import matplotlib.pyplot as plt
from PIL import Image

# !ls data
plt.imshow(Image.open('data/Rainier1.png'))
plt.show()
# Out:
# Rainier1.png  Rainier2.png  Rainier3.png  Rainier4.png	Rainier5.png  Rainier6.png

# %% [markdown]
# ## Détection des coins de Harris

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from harris_image import harris_corner_detector,detect_and_draw_corners


image_path = 'data/Rainier1.png'
im = cv2.imread(image_path)  # Cette fonction charge l'image en format BGR
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)  # Convertissez l'image en RGB si nécessaire

sigma=1.5
thresh= 0.01
nms= 5

m = detect_and_draw_corners(im, sigma, thresh, nms)
plt.imshow(m)
plt.show()
# Out:
# harris_corner_detector
